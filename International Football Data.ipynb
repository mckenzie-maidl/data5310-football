# %%
import pandas as pd
import numpy as np
import altair as alt

# %%
goals = pd.read_csv("goalscorers.csv")

# %%
goals.head()
# Out:
#        date  home_team away_team       team            scorer  minute  \
# 0  7/2/1916      Chile   Uruguay    Uruguay   José Piendibene    44.0
# 1  7/2/1916      Chile   Uruguay    Uruguay  Isabelino Gradín    55.0
# 2  7/2/1916      Chile   Uruguay    Uruguay  Isabelino Gradín    70.0
# 3  7/2/1916      Chile   Uruguay    Uruguay   José Piendibene    75.0
# 4  7/6/1916  Argentina     Chile  Argentina     Alberto Ohaco     2.0
#
#   own_goal penalty
# 0    False   False
# 1    False   False
# 2    False   False
# 3    False   False
# 4    False   False

# %%
goals['Point earned'] = np.where(goals['own_goal']=='False', '0', '1')
goals['Point earned'] = goals['Point earned'].astype(int)
goals.head()
# Out:
#        date  home_team away_team       team            scorer  minute  \
# 0  7/2/1916      Chile   Uruguay    Uruguay   José Piendibene    44.0
# 1  7/2/1916      Chile   Uruguay    Uruguay  Isabelino Gradín    55.0
# 2  7/2/1916      Chile   Uruguay    Uruguay  Isabelino Gradín    70.0
# 3  7/2/1916      Chile   Uruguay    Uruguay   José Piendibene    75.0
# 4  7/6/1916  Argentina     Chile  Argentina     Alberto Ohaco     2.0
#
#   own_goal penalty  Point earned
# 0    False   False             1
# 1    False   False             1
# 2    False   False             1
# 3    False   False             1
# 4    False   False             1

# %%
goals['Home goals'] = goals[goals['team'] == goals['home_team']].groupby(['date', 'home_team'])['Point earned'].transform('sum')
goals['Away goals'] = goals[goals['team'] == goals['away_team']].groupby(['date', 'away_team'])['Point earned'].transform('sum')
goals.head()
# Out:
#        date  home_team away_team       team            scorer  minute  \
# 0  7/2/1916      Chile   Uruguay    Uruguay   José Piendibene    44.0
# 1  7/2/1916      Chile   Uruguay    Uruguay  Isabelino Gradín    55.0
# 2  7/2/1916      Chile   Uruguay    Uruguay  Isabelino Gradín    70.0
# 3  7/2/1916      Chile   Uruguay    Uruguay   José Piendibene    75.0
# 4  7/6/1916  Argentina     Chile  Argentina     Alberto Ohaco     2.0
#
#   own_goal penalty  Point earned  Home goals  Away goals
# 0    False   False             1         NaN         4.0
# 1    False   False             1         NaN         4.0
# 2    False   False             1         NaN         4.0
# 3    False   False             1         NaN         4.0
# 4    False   False             1         6.0         NaN

# %%
goals['Home goals'] = goals['Home goals'].fillna(0).astype(int)
goals['Away goals'] = goals['Away goals'].fillna(0).astype(int)
goals.iloc[0:20, :]
# Out:
#          date  home_team away_team       team                        scorer  \
# 0    7/2/1916      Chile   Uruguay    Uruguay               José Piendibene
# 1    7/2/1916      Chile   Uruguay    Uruguay              Isabelino Gradín
# 2    7/2/1916      Chile   Uruguay    Uruguay              Isabelino Gradín
# 3    7/2/1916      Chile   Uruguay    Uruguay               José Piendibene
# 4    7/6/1916  Argentina     Chile  Argentina                 Alberto Ohaco
# 5    7/6/1916  Argentina     Chile      Chile                Telésforo Báez
# 6    7/6/1916  Argentina     Chile  Argentina            Juan Domingo Brown
# 7    7/6/1916  Argentina     Chile  Argentina            Juan Domingo Brown
# 8    7/6/1916  Argentina     Chile  Argentina          Alberto Marcovecchio
# 9    7/6/1916  Argentina     Chile  Argentina                 Alberto Ohaco
# 10   7/6/1916  Argentina     Chile  Argentina          Alberto Marcovecchio
# ...

# %%
goals['Home goals'] = goals.groupby(['date', 'home_team'])['Home goals'].transform('max')
goals['Away goals'] = goals.groupby(['date', 'away_team'])['Away goals'].transform('max')
goals.iloc[0:20, :]
# Out:
#          date  home_team away_team       team                        scorer  \
# 0    7/2/1916      Chile   Uruguay    Uruguay               José Piendibene
# 1    7/2/1916      Chile   Uruguay    Uruguay              Isabelino Gradín
# 2    7/2/1916      Chile   Uruguay    Uruguay              Isabelino Gradín
# 3    7/2/1916      Chile   Uruguay    Uruguay               José Piendibene
# 4    7/6/1916  Argentina     Chile  Argentina                 Alberto Ohaco
# 5    7/6/1916  Argentina     Chile      Chile                Telésforo Báez
# 6    7/6/1916  Argentina     Chile  Argentina            Juan Domingo Brown
# 7    7/6/1916  Argentina     Chile  Argentina            Juan Domingo Brown
# 8    7/6/1916  Argentina     Chile  Argentina          Alberto Marcovecchio
# 9    7/6/1916  Argentina     Chile  Argentina                 Alberto Ohaco
# 10   7/6/1916  Argentina     Chile  Argentina          Alberto Marcovecchio
# ...

# %%
#goals['winner'] = np.where(goals['Away goals'] >= goals['Home goals'], goals['away_team'], goals['home_team'])

goals['winner'] = np.where(goals['Away goals'] > goals['Home goals'], goals['away_team'],
                            np.where(goals['Away goals'] < goals['Home goals'], goals['home_team'], 'tie'))
goals.iloc[0:20, :]
# Out:
#          date  home_team away_team       team                        scorer  \
# 0    7/2/1916      Chile   Uruguay    Uruguay               José Piendibene
# 1    7/2/1916      Chile   Uruguay    Uruguay              Isabelino Gradín
# 2    7/2/1916      Chile   Uruguay    Uruguay              Isabelino Gradín
# 3    7/2/1916      Chile   Uruguay    Uruguay               José Piendibene
# 4    7/6/1916  Argentina     Chile  Argentina                 Alberto Ohaco
# 5    7/6/1916  Argentina     Chile      Chile                Telésforo Báez
# 6    7/6/1916  Argentina     Chile  Argentina            Juan Domingo Brown
# 7    7/6/1916  Argentina     Chile  Argentina            Juan Domingo Brown
# 8    7/6/1916  Argentina     Chile  Argentina          Alberto Marcovecchio
# 9    7/6/1916  Argentina     Chile  Argentina                 Alberto Ohaco
# 10   7/6/1916  Argentina     Chile  Argentina          Alberto Marcovecchio
# ...

# %%
goals['winner team' ]= np.where(goals['winner'] == goals['home_team'], 'Home',
                            np.where(goals['winner'] == goals['away_team'], 'Away', 'tie'))
goals.iloc[0:20, :]
# Out:
#          date  home_team away_team       team                        scorer  \
# 0    7/2/1916      Chile   Uruguay    Uruguay               José Piendibene
# 1    7/2/1916      Chile   Uruguay    Uruguay              Isabelino Gradín
# 2    7/2/1916      Chile   Uruguay    Uruguay              Isabelino Gradín
# 3    7/2/1916      Chile   Uruguay    Uruguay               José Piendibene
# 4    7/6/1916  Argentina     Chile  Argentina                 Alberto Ohaco
# 5    7/6/1916  Argentina     Chile      Chile                Telésforo Báez
# 6    7/6/1916  Argentina     Chile  Argentina            Juan Domingo Brown
# 7    7/6/1916  Argentina     Chile  Argentina            Juan Domingo Brown
# 8    7/6/1916  Argentina     Chile  Argentina          Alberto Marcovecchio
# 9    7/6/1916  Argentina     Chile  Argentina                 Alberto Ohaco
# 10   7/6/1916  Argentina     Chile  Argentina          Alberto Marcovecchio
# ...
