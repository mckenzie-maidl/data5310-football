# %%
# import
import pandas as pd
import numpy as np
import altair as alt

# enable Altair to work with data with <5k rows
alt.data_transformers.enable('json')
# Out:
# DataTransformerRegistry.enable('json')

# %%
# load data
goals = pd.read_csv('goals.csv')
# Out:
# /var/folders/2r/xnmj22_136g1440s_kpc4g980000gn/T/ipykernel_10701/1502805003.py:2: DtypeWarning: Columns (6,7) have mixed types. Specify dtype option on import or set low_memory=False.
#   goals = pd.read_csv('goals.csv')

# %%
# view data
goals.head(30)
# Out:
#           date  home_team away_team scorer_team                        scorer  \
# 0   1916-07-02      Chile   Uruguay     Uruguay               José Piendibene
# 1   1916-07-02      Chile   Uruguay     Uruguay              Isabelino Gradín
# 2   1916-07-02      Chile   Uruguay     Uruguay              Isabelino Gradín
# 3   1916-07-02      Chile   Uruguay     Uruguay               José Piendibene
# 4   1916-07-06  Argentina     Chile   Argentina                 Alberto Ohaco
# 5   1916-07-06  Argentina     Chile       Chile                Telésforo Báez
# 6   1916-07-06  Argentina     Chile   Argentina            Juan Domingo Brown
# 7   1916-07-06  Argentina     Chile   Argentina            Juan Domingo Brown
# 8   1916-07-06  Argentina     Chile   Argentina          Alberto Marcovecchio
# 9   1916-07-06  Argentina     Chile   Argentina                 Alberto Ohaco
# 10  1916-07-06  Argentina     Chile   Argentina          Alberto Marcovecchio
# 11  1916-07-08     Brazil     Chile      Brazil  Demóstenes Correia de Syllos
# 12  1916-07-08     Brazil     Chile       Chile              Hernando Salazar
# 13  1916-07-10  Argentina    Brazil   Argentina            José Durand Laguna
# 14  1916-07-10  Argentina    Brazil      Brazil          Manoel Alencar Monte
# 15  1916-07-12     Brazil   Uruguay      Brazil           Arthur Friedenreich
# 16  1916-07-12     Brazil   Uruguay     Uruguay              Isabelino Gradín
# 17  1916-07-12     Brazil   Uruguay     Uruguay                  Jose Tognola
# 18  1917-09-30    Uruguay     Chile     Uruguay                Carlos Scarone
# 19  1917-09-30    Uruguay     Chile     Uruguay                  Ángel Romano
# 20  1917-09-30    Uruguay     Chile     Uruguay                Carlos Scarone
# 21  1917-09-30    Uruguay     Chile     Uruguay                  Ángel Romano
# 22  1917-10-03  Argentina    Brazil      Brazil                          Neco
# 23  1917-10-03  Argentina    Brazil   Argentina                Pedro Calomino
# 24  1917-10-03  Argentina    Brazil      Brazil                Silvio Lagreca
# 25  1917-10-03  Argentina    Brazil   Argentina                 Alberto Ohaco
# 26  1917-10-03  Argentina    Brazil   Argentina                 Alberto Ohaco
# 27  1917-10-03  Argentina    Brazil   Argentina                Antonio Blanco
# 28  1917-10-06  Argentina     Chile   Argentina                   Luis García
# 29  1917-10-07    Uruguay    Brazil     Uruguay                Héctor Scarone
#
#     minute own_goal penalty  point_earned  home_goals  away_goals     winner  \
# 0     44.0    False   False             1           0           4    Uruguay
# 1     55.0    False   False             1           0           4    Uruguay
# 2     70.0    False   False             1           0           4    Uruguay
# 3     75.0    False   False             1           0           4    Uruguay
# 4      2.0    False   False             1           6           1  Argentina
# 5     44.0    False   False             1           6           1  Argentina
# 6     60.0    False    True             1           6           1  Argentina
# 7     62.0    False    True             1           6           1  Argentina
# 8     67.0    False   False             1           6           1  Argentina
# 9     75.0    False   False             1           6           1  Argentina
# 10    81.0    False   False             1           6           1  Argentina
# 11    29.0    False   False             1           1           1        Tie
# 12    85.0    False   False             1           1           1        Tie
# 13    10.0    False   False             1           1           1        Tie
# 14    23.0    False   False             1           1           1        Tie
# 15     8.0    False   False             1           1           2    Uruguay
# 16    58.0    False   False             1           1           2    Uruguay
# 17    77.0    False   False             1           1           2    Uruguay
# 18    20.0    False   False             1           4           0    Uruguay
# 19    44.0    False   False             1           4           0    Uruguay
# 20    62.0    False    True             1           4           0    Uruguay
# 21    75.0    False   False             1           4           0    Uruguay
# 22     8.0    False   False             1           4           2  Argentina
# 23    15.0    False   False             1           4           2  Argentina
# 24    39.0    False    True             1           4           2  Argentina
# 25    56.0    False    True             1           4           2  Argentina
# 26    58.0    False    True             1           4           2  Argentina
# 27    80.0    False   False             1           4           2  Argentina
# 28    76.0     True   False             1           1           0  Argentina
# 29     8.0    False   False             1           4           0    Uruguay
#
#    winner_team  penalty_point  home_penalties  away_penalties
# 0         Away              0               0               0
# 1         Away              0               0               0
# 2         Away              0               0               0
# 3         Away              0               0               0
# 4         Home              0               2               0
# 5         Home              0               2               0
# 6         Home              1               2               0
# 7         Home              1               2               0
# 8         Home              0               2               0
# 9         Home              0               2               0
# 10        Home              0               2               0
# 11         Tie              0               0               0
# 12         Tie              0               0               0
# 13         Tie              0               0               0
# 14         Tie              0               0               0
# 15        Away              0               0               0
# 16        Away              0               0               0
# 17        Away              0               0               0
# 18        Home              0               1               0
# 19        Home              0               1               0
# 20        Home              1               1               0
# 21        Home              0               1               0
# 22        Home              0               2               1
# 23        Home              0               2               1
# 24        Home              1               2               1
# 25        Home              1               2               1
# 26        Home              1               2               1
# 27        Home              0               2               1
# 28        Home              0               0               0
# 29        Home              0               0               0

# %%
#

# %%
def custom_theme():
    return {
        'config': {
            'view': {
                'height': 400,
                'width': 400,
                
            },
            "axis": {
                "labelFontSize": 12, 
                "titleFontSize": 13,
            },
            "title": {
              "fontSize": 14
            },
            "legend": {
              "direction": "horizontal",
              "labelFontSize": 12,
              "titleFontSize": 13
            },
            'mark': {
                'fill': '#10773c'
            }
        }
    }
