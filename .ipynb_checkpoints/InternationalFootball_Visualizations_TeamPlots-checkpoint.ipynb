# %%
# import
import pandas as pd
import numpy as np
import altair as alt
import json
import pycountry_convert as pc

# enable Altair to work with data with <5k rows
alt.data_transformers.enable('json')
# Out:
# DataTransformerRegistry.enable('json')

# %%
# load data
goals = pd.read_csv('goals.csv')

# %%
# view data
goals.head()
# Out:
#          date  home_team away_team scorer_team            scorer  minute  \
# 0  1916-07-02      Chile   Uruguay     Uruguay   José Piendibene    44.0
# 1  1916-07-02      Chile   Uruguay     Uruguay  Isabelino Gradín    55.0
# 2  1916-07-02      Chile   Uruguay     Uruguay  Isabelino Gradín    70.0
# 3  1916-07-02      Chile   Uruguay     Uruguay   José Piendibene    75.0
# 4  1916-07-06  Argentina     Chile   Argentina     Alberto Ohaco     2.0
#
#    own_goal  penalty  point_earned  home_goals  away_goals     winner  \
# 0     False    False             1           0           4    Uruguay
# 1     False    False             1           0           4    Uruguay
# 2     False    False             1           0           4    Uruguay
# 3     False    False             1           0           4    Uruguay
# 4     False    False             1           6           1  Argentina
#
#   winner_team  penalty_point  home_penalties  away_penalties
# 0        Away              0               0               0
# 1        Away              0               0               0
# 2        Away              0               0               0
# 3        Away              0               0               0
# 4        Home              0               2               0

# %%
# group data by game
game_cols = ['date', 'home_team', 'away_team', 'home_goals', 'away_goals', 
        'winner', 'winner_team', 'home_penalties', 'away_penalties']

games = goals[game_cols].drop_duplicates()

games['year'] =  games['date'].astype('datetime64[ns]').dt.year 

games.reset_index(drop=True, inplace=True)

print(games.shape)
games.head()
# Out:
# (13986, 10)
#          date  home_team away_team  home_goals  away_goals     winner  \
# 0  1916-07-02      Chile   Uruguay           0           4    Uruguay
# 1  1916-07-06  Argentina     Chile           6           1  Argentina
# 2  1916-07-08     Brazil     Chile           1           1        Tie
# 3  1916-07-10  Argentina    Brazil           1           1        Tie
# 4  1916-07-12     Brazil   Uruguay           1           2    Uruguay
#
#   winner_team  home_penalties  away_penalties  year
# 0        Away               0               0  1916
# 1        Home               2               0  1916
# 2         Tie               0               0  1916
# 3         Tie               0               0  1916
# 4        Away               0               0  1916

# %%
# group data by team
team_cols = ['date', 'year', 'team', 'opponent', 'goals', 'opponent_goals', 
        'penalties_awarded', 'penalties_caused', 'won', 'home']

home_teams = games.copy()
home_teams = home_teams.rename(columns={'home_team': 'team',
                                        'away_team': 'opponent',
                                        'home_goals': 'goals',
                                        'away_goals': 'opponent_goals',
                                        'home_penalties': 'penalties_awarded',
                                        'away_penalties': 'penalties_caused'
                                       })
home_teams['won'] = np.where(home_teams['team'] == home_teams['winner'], 1, 0)
home_teams['home'] = 1
home_teams = home_teams[team_cols]

away_teams = games.copy()
away_teams = away_teams.rename(columns={'away_team': 'team',
                                        'home_team': 'opponent',
                                        'away_goals': 'goals',
                                        'home_goals': 'opponent_goals',
                                        'away_penalties': 'penalties_awarded',
                                        'home_penalties': 'penalties_caused'
                                       })
away_teams['won'] = np.where(away_teams['team'] == away_teams['winner'], 1, 0)
away_teams['home'] = 0
away_teams = away_teams[team_cols]

teams = pd.concat([home_teams, away_teams], axis=0)

teams.reset_index(drop=True, inplace=True)

# get continent from country
def get_continent(name):
    continents = {'SA': 'South America', 'EU': 'Europe', 'NA': 'North America', 
                  'AF': 'Africa', 'AS': 'Asia', 'OC': 'Oceania', None: None}
    try:
        code = pc.country_name_to_country_alpha2(name)
        cont = pc.country_alpha2_to_continent_code(code)
        return continents[cont]
    except: 
        pass

teams['team_continent'] = teams['team'].apply(get_continent)
teams['team_continent'] = np.where(teams['team'].isin(['Republic of Ireland','Northern Ireland','Wales', 
                                                     'Scotland','England', 'Kosovo']), 'Europe',
                          np.where(teams['team'].isin(['China PR', 'Timor-Leste']), 'Asia',
                          np.where(teams['team'].isin(['DR Congo']), 'Africa', 
                          np.where(teams['team'].isin(['Tahiti']), 'Oceania', teams['team_continent']))))

teams.head()
# Out:
#          date  year       team opponent  goals  opponent_goals  \
# 0  1916-07-02  1916      Chile  Uruguay      0               4
# 1  1916-07-06  1916  Argentina    Chile      6               1
# 2  1916-07-08  1916     Brazil    Chile      1               1
# 3  1916-07-10  1916  Argentina   Brazil      1               1
# 4  1916-07-12  1916     Brazil  Uruguay      1               2
#
#    penalties_awarded  penalties_caused  won  home team_continent
# 0                  0                 0    0     1  South America
# 1                  2                 0    1     1  South America
# 2                  0                 0    0     1  South America
# 3                  0                 0    0     1  South America
# 4                  0                 0    0     1  South America

# %%
# REMOVE????

# filter to teams that play at least the mean count of games per year
mean_counts_team = pd.DataFrame(teams.groupby(['team', 'year'])['date'].count()
                          ).reset_index().rename(columns={'date': 'mean_games_team'})

mean_counts_year = pd.DataFrame(mean_counts_team.groupby(['year'])['mean_games_team'].mean()
                               ).reset_index().rename(columns={'mean_games_team': 'mean_games_year'})

teams_maj = pd.merge(teams, mean_counts_team, on=['year', 'team'])
teams_maj = pd.merge(teams_maj, mean_counts_year, on='year')

teams_maj = teams_maj[teams_maj['mean_games_team'] >= teams_maj['mean_games_year']]

teams_maj.head()
# Out:
#          date  year    team   opponent  goals  opponent_goals  \
# 0  1916-07-02  1916   Chile    Uruguay      0               4
# 1  1916-07-06  1916   Chile  Argentina      1               6
# 2  1916-07-08  1916   Chile     Brazil      1               1
# 5  1916-07-08  1916  Brazil      Chile      1               1
# 6  1916-07-12  1916  Brazil    Uruguay      1               2
#
#    penalties_awarded  penalties_caused  won  home team_continent  \
# 0                  0                 0    0     1  South America
# 1                  0                 2    0     0  South America
# 2                  0                 0    0     0  South America
# 5                  0                 0    0     1  South America
# 6                  0                 0    0     1  South America
#
#    mean_games_team  mean_games_year
# 0                3              2.5
# 1                3              2.5
# 2                3              2.5
# 5                3              2.5
# 6                3              2.5

# %%
# team summaries for use in world map
teams_sum = teams.copy()

# get earliest/latest year
teams_sum['min_year'] = teams_sum.groupby(['team'])['year'].transform('min')
teams_sum['latest_year'] = teams_sum.groupby(['team'])['year'].transform('max')

def bin_years(year):
    if year < 1940:
        return '1916-1940'
    elif year < 1960:
        return '1941-1960'
    elif year < 1980:
        return '1961-1980'
    elif year < 2000:
        return '1981-2000'
    else:
        return '2001-2023'
    
teams_sum['min_year_binned'] = teams_sum['min_year'].apply(bin_years)

# get count games
teams_sum['count_games'] = teams_sum.groupby(['team'])['team'].transform('count')


# add ISO 3166-1 numeric codes to teams data
iso = pd.read_csv('iso_3166.csv')
teams_sum = pd.merge(teams_sum, iso, left_on='team', right_on='name', how='left')

# get subset of columns
teams_sum.drop(columns=['date','year', 'opponent','goals','opponent_goals','penalties_awarded','penalties_caused',
                       'won','home','name'], axis=1, inplace=True)

# drop duplicates
teams_sum.drop_duplicates(inplace=True)

# reset index
teams_sum.reset_index(drop=True, inplace=True)

print(teams_sum.shape)
teams_sum.head()
# Out:
# (214, 7)
#         team team_continent  min_year  latest_year min_year_binned  \
# 0      Chile  South America      1916         2022       1916-1940
# 1  Argentina  South America      1916         2022       1916-1940
# 2     Brazil  South America      1916         2022       1916-1940
# 3    Uruguay  South America      1916         2022       1916-1940
# 4   Paraguay  South America      1921         2022       1916-1940
#
#    count_games   id
# 0          365  152
# 1          419   32
# 2          440   76
# 3          413  858
# 4          346  600

# %%
# set custom theme
def custom_theme():
    return {
        'config': {
            'view': {
                'height': 600,
                'width': 600,
                
            },
            "axis": {
                "labelFontSize": 12, 
                "titleFontSize": 13,
            },
            "title": {
              "fontSize": 14
            },
            "legend": {
              "labelFontSize": 12,
              "titleFontSize": 13
            },
            'mark': {
                'fill': '#005391'
            }
        }
    }

# register the custom theme under a chosen name
alt.themes.register('custom_theme', custom_theme)

# enable the newly registered theme
alt.themes.enable('custom_theme')
# Out:
# ThemeRegistry.enable('custom_theme')

# %% [markdown]
# #### Plot 1: Map of Countries

# %%
# world topo, edited to add Kosovo
world_topo = alt.topo_feature('world_topo.json', 'countries')

# %%
# plot (option 1)
domain = ['1916-1940', '1941-1960', '1961-1980', '1981-2000', '2001-2023', 'No Data']
colors = ['#005391', '#0074cc', '#1a9cff', '#66bdff', '#b3deff', '#E0E0E0']

alt.layer(
    # Earth sphere base layer
    alt.Chart({'sphere': True}).mark_geoshape(fill='#E6F3FF'
        ).project(type='naturalEarth1'
    ),
    # geographic reference lines
    alt.Chart({'graticule': True}).mark_geoshape(
        stroke='white', strokeWidth=0.5, fill=None
    ),
    # world countries
    alt.Chart(world_topo).mark_geoshape(
        stroke='white', strokeWidth=0.5
    ).transform_lookup(
        lookup='id', from_=alt.LookupData(data=teams_sum, key='id', fields=['min_year_binned'])
    ).encode(
        color = alt.condition('datum.min_year_binned != null', 'min_year_binned:N', alt.value('#E0E0E0'), 
                              scale=alt.Scale(domain=domain, range=colors),
                              title='Appearance Year')
    )
).properties(
    height=325,
    title = "First Appearance in Men's International Football (1916-2023)"
)
# Out:
# alt.LayerChart(...)

# %%
# plot (option 2)
domain = ['1916-1940', '1941-1960', '1961-1980', '1981-2000', '2001-2023', 'No Data']
colors = ['#005391', '#0074cc', '#1a9cff', '#66bdff', '#b3deff', '#E0E0E0']

# world countries
alt.Chart(world_topo).mark_geoshape(
    stroke='white', strokeWidth=0.5
).transform_filter(
    # remove Antarctica
    'datum.id!=10'
).project(
    type='naturalEarth1'
).transform_lookup(
    lookup='id', from_=alt.LookupData(data=teams_sum, key='id', fields=['min_year_binned'])
).encode(
    color = alt.condition('datum.min_year_binned != null', 'min_year_binned:N', alt.value('#E0E0E0'), 
                          scale=alt.Scale(domain=domain, range=colors),
                          title='Appearance Year')
).properties(
    height=350,
    width=750,
    title = "First Appearance in Men's International Football (1916-2023)"
)
# Out:
# alt.Chart(...)

# %% [markdown]
# #### Plot 2: Teams that Win Most by Year

# %%
color = []

alt.Chart(teams).mark_bar(
).transform_aggregate(
    # count of games and wins by team/year
    count_games='count(won)',
    count_wins='sum(won)',
    groupby=['team', 'year', 'team_continent']
).transform_window(
    # max values by year
    max_games='max(count_games)',
    frame=[None, None],
    groupby=['year']
).transform_calculate(
    # mid-point for max games
    mid='datum.max_games/2',
    # win-rate
    prop_win='datum.count_wins/datum.count_games'
).transform_filter(
    # teams that played most games per year
    'datum.count_games >= datum.mid'
).transform_window(
    # team(s) with highest win-rate
    max_prop='max(prop_win)',
    frame=[None, None],
    groupby=['year']
).transform_filter(
    # filter out teams without highest win-rate
    'datum.prop_win == datum.max_prop'
).transform_joinaggregate(
    # max games for teams with highest win-rates
    count_games_max='max(count_games)',
    groupby=['year']
).transform_filter(
    # when there is a tie, take the team who played the most games
    'datum.count_games == datum.count_games_max'
).transform_calculate(
    # 1996 still has a tie
    team_continent_calc='datum.year != 1996 ? datum.team_continent : "Tie (Africa, North America)"',
).encode(
    alt.Y('year:O', axis=alt.Axis(values=[1920, 1925, 1930, 1935, 1940, 1945, 1950, 1955, 1960, 1965,
                                          1970, 1975, 1980, 1985, 1990, 1995, 2000, 2005, 2010, 2015, 2020])),
    alt.X('mean(max_prop):Q'),
    alt.Color('team_continent_calc:N')
).properties(height=800)
# Out:
# alt.Chart(...)

# %%
color = []

base = alt.Chart(teams).transform_aggregate(
    # count of games and wins by team/year
    count_games='count(won)',
    count_wins='sum(won)',
    groupby=['team', 'year', 'team_continent']
).transform_window(
    # max values by year
    max_games='max(count_games)',
    frame=[None, None],
    groupby=['year']
).transform_calculate(
    # mid-point for max games
    mid='datum.max_games/2',
    # win-rate
    prop_win='datum.count_wins/datum.count_games'
).transform_filter(
    # teams that played most games per year
    'datum.count_games >= datum.mid'
).transform_window(
    # team(s) with highest win-rate
    max_prop='max(prop_win)',
    frame=[None, None],
    groupby=['year']
).transform_filter(
    # filter out teams without highest win-rate
    'datum.prop_win == datum.max_prop'
).transform_joinaggregate(
    # max games for teams with highest win-rates
    count_games_max='max(count_games)',
    groupby=['year']
).transform_filter(
    # when there is a tie, take the team who played the most games
    'datum.count_games == datum.count_games_max'
).transform_calculate(
    # 1996 still has a tie
    team_continent_calc='datum.year != 1996 ? datum.team_continent : "Tie (Africa, North America)"',
).encode(
    alt.Y('year:O', axis=alt.Axis(values=[1920, 1925, 1930, 1935, 1940, 1945, 1950, 1955, 1960, 1965,
                                          1970, 1975, 1980, 1985, 1990, 1995, 2000, 2005, 2010, 2015, 2020])),
    alt.X('mean(max_prop):Q'),
    alt.Color('team_continent_calc:N', legend=alt.Legend(orient='top'))
)

c1 = base.mark_bar().properties(height=1000)

c2 = base.mark_text(align='left', dx=2, fontSize=10).transform_window(
            t = 'min(team)',
            frame=[None, None],
            groupby=['year']).encode(alt.Text('t:N'))

c3 = base.mark_text(align='left', dx=50, fontSize=10, lineBreak=r'\n').encode(alt.Text('t:N'))


countries = ['Uruguay','Uruguay','Brazil','Uruguay','Argentina','Uruguay','Uruguay','Uruguay','Argentina',
             'Uruguay','Arentina','Latvia','Argentina','Uruguay','Estonia','Latvia','Sweden','Italy','Uruguay',
             'Latvia','Germany','Italy','Peru','Argentina','Uruguay', 'Argentina/Brazil', 'Argentina',
             'Argentina','Argentina','Mexico','Uruguay','France','Austria/Hungary','Argentina','Uruguay',
             'Mexico','Brazil','Argentina','South Korea','Bulgaria/Russia','Brazil','Bolivia']

text = '\n'.join(countries)

c1 + c2 + c3
# Out:
# alt.LayerChart(...)

# %% [markdown]
# #### Plot 3: Teams that Kick/Cause the Most Penalities

# %%
c1 = alt.Chart(teams).mark_bar().transform_aggregate(
    mean_penalties_caused = 'mean(penalties_caused)',
    tot_games = 'count(won)',
    tot_wins = 'sum(won)',
    groupby=['team']
).transform_calculate(
    mean_prop_win = 'datum.tot_wins / datum.tot_games'
).transform_window(
    rank='rank(mean_penalties_caused)',
    sort=[alt.SortField('mean_penalties_caused', order='descending')],
    frame = [None, None]
).transform_filter(
    'datum.rank <= 50'
).encode(
    alt.Y('team:N', sort=alt.EncodingSortField(field='mean_penalties_caused', order='descending')),
    alt.X('mean_penalties_caused:Q', scale=alt.Scale(domain=[0, 0.6])),
    alt.Color('mean_prop_win:Q')
).properties(width=300)

c2 = alt.Chart(teams).mark_bar().transform_aggregate(
    mean_penalties_awarded = 'mean(penalties_awarded)',
    tot_games = 'count(won)',
    tot_wins = 'sum(won)',
    groupby=['team']
).transform_calculate(
    mean_prop_win = 'datum.tot_wins / datum.tot_games'
).transform_window(
    rank='rank(mean_penalties_awarded)',
    sort=[alt.SortField('mean_penalties_awarded', order='descending')],
    frame = [None, None]
).transform_filter(
    'datum.rank <= 50'
).encode(
    alt.Y('team:N', sort=alt.EncodingSortField(field='mean_penalties_awarded', order='descending')),
    alt.X('mean_penalties_awarded:Q', scale=alt.Scale(domain=[0, 0.6])),
    alt.Color('mean_prop_win:Q')
).properties(width=300)

alt.hconcat(c1,c2)
# Out:
# alt.HConcatChart(...)

# %% [markdown]
# #### Plot 4: Highest Scoring Teams per Game

# %%
alt.Chart(teams).mark_circle(opacity=0.5).transform_aggregate(
    mean_goals = 'mean(goals)',
    mean_opp_goals = 'mean(opponent_goals)',
    tot_games = 'count(won)',
    tot_wins = 'sum(won)',
    groupby=['team', 'team_continent']
).transform_calculate(
    mean_prop_win = 'datum.tot_wins / datum.tot_games'
).encode(
    alt.X('mean_goals:Q'),
    alt.Y('mean_opp_goals:Q'),
    alt.Color('team_continent:N'),
    alt.Size('mean_prop_win:Q'),
    alt.Tooltip('team:N')
)
# Out:
# alt.Chart(...)
