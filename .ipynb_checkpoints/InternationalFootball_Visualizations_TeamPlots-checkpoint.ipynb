# %%
# import
import pandas as pd
import numpy as np
import altair as alt
from vega_datasets import data

# enable Altair to work with data with <5k rows
alt.data_transformers.enable('json')
# Out:
# DataTransformerRegistry.enable('json')

# %%
# load data
goals = pd.read_csv('goals.csv')

# %%
# view data
goals.head()
# Out:
#          date  home_team away_team scorer_team            scorer  minute  \
# 0  1916-07-02      Chile   Uruguay     Uruguay   José Piendibene    44.0
# 1  1916-07-02      Chile   Uruguay     Uruguay  Isabelino Gradín    55.0
# 2  1916-07-02      Chile   Uruguay     Uruguay  Isabelino Gradín    70.0
# 3  1916-07-02      Chile   Uruguay     Uruguay   José Piendibene    75.0
# 4  1916-07-06  Argentina     Chile   Argentina     Alberto Ohaco     2.0
#
#    own_goal  penalty  point_earned  home_goals  away_goals     winner  \
# 0     False    False             1           0           4    Uruguay
# 1     False    False             1           0           4    Uruguay
# 2     False    False             1           0           4    Uruguay
# 3     False    False             1           0           4    Uruguay
# 4     False    False             1           6           1  Argentina
#
#   winner_team  penalty_point  home_penalties  away_penalties
# 0        Away              0               0               0
# 1        Away              0               0               0
# 2        Away              0               0               0
# 3        Away              0               0               0
# 4        Home              0               2               0

# %%
# group data by game
cols = ['date', 'home_team', 'away_team', 'home_goals', 'away_goals', 
        'winner', 'winner_team', 'home_penalties', 'away_penalties']

games = goals[cols].drop_duplicates()

print(games.shape)
games.head()
# Out:
# (13986, 9)
#           date  home_team away_team  home_goals  away_goals     winner  \
# 0   1916-07-02      Chile   Uruguay           0           4    Uruguay
# 4   1916-07-06  Argentina     Chile           6           1  Argentina
# 11  1916-07-08     Brazil     Chile           1           1        Tie
# 13  1916-07-10  Argentina    Brazil           1           1        Tie
# 15  1916-07-12     Brazil   Uruguay           1           2    Uruguay
#
#    winner_team  home_penalties  away_penalties
# 0         Away               0               0
# 4         Home               2               0
# 11         Tie               0               0
# 13         Tie               0               0
# 15        Away               0               0

# %%
# set custom theme
def custom_theme():
    return {
        'config': {
            'view': {
                'height': 400,
                'width': 400,
                
            },
            "axis": {
                "labelFontSize": 12, 
                "titleFontSize": 13,
            },
            "title": {
              "fontSize": 14
            },
            "legend": {
              "direction": "horizontal",
              "labelFontSize": 12,
              "titleFontSize": 13
            },
            'mark': {
                'fill': '#005391'
            }
        }
    }

# %%
# PLOT 1: map of which countries have been playing over time

world = data.world_110m.url
#alt.Chart(alt.topo_feature(world, 'countries')).mark_geoshape()


alt.layer(
    # use the sphere of the Earth as the base layer
    alt.Chart({'sphere': True}).mark_geoshape(
        fill='#e6f3ff'
    ).project(type='naturalEarth1'
    ),
    # add a graticule for geographic reference lines
    alt.Chart({'graticule': True}).mark_geoshape(
        stroke='#ffffff', strokeWidth=0.5
    ),
    # and then the countries of the world
    alt.Chart(alt.topo_feature(world, 'countries')).mark_geoshape(
        fill='#005391', stroke='white', strokeWidth=0.5
    )
).properties(
    width=600,
    height=400
)

# #f2f2f2
# Out:
# alt.LayerChart(...)
